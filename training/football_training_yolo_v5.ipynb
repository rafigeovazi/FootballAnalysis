# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ultralytics in c:\users\rafig\appdata\roaming\python\python312\site-packages (8.2.69)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from ultralytics) (3.9.1)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from ultralytics) (1.14.0)
# Requirement already satisfied: torch>=1.8.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from ultralytics) (2.4.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from ultralytics) (0.19.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in c:\users\rafig\appdata\roaming\python\python312\site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\rafig\appdata\roaming\python\python312\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from ultralytics) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (2024.7.4)
# Requirement already satisfied: filelock in c:\users\rafig\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in c:\users\rafig\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: networkx in c:\users\rafig\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\rafig\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\rafig\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (72.1.0)
# Requirement already satisfied: colorama in c:\users\rafig\appdata\roaming\python\python312\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: roboflow in c:\users\rafig\appdata\roaming\python\python312\site-packages (1.1.37)
# Requirement already satisfied: certifi in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (2024.7.4)
# Requirement already satisfied: chardet==4.0.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (4.0.0)
# Requirement already satisfied: idna==3.7 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (3.9.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (10.4.0)
# Requirement already satisfied: python-dateutil in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (2.2.2)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\rafig\appdata\roaming\python\python312\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in c:\users\rafig\appdata\roaming\python\python312\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from matplotlib->roboflow) (4.53.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rafig\appdata\roaming\python\python312\site-packages (from requests->roboflow) (3.3.2)

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="rKVuWYTXwA4e6jVc03VI")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(9)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import shutil

shutil.move('football-players-detection-9/train',
            'football-players-detection-9/football-players-detection-9/train'
            )
shutil.move('football-players-detection-9/valid',
            'football-players-detection-9/football-players-detection-9/valid'
            )
shutil.move('football-players-detection-9/test',
            'football-players-detection-9/football-players-detection-9/test'
            )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Program Files\Python312\Lib\shutil.py:847, in move(src, dst, copy_function)
#     846 try:
# --> 847     os.rename(src, real_dst)
#     848 except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'football-players-detection-9/train' -> 'football-players-detection-9/football-players-detection-9/train\\train'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import shutil
# ----> 3 shutil.move('football-players-detection-9/train',
#       4             'football-players-detection-9/football-players-detection-9/train'
#       5             )
#       6 shutil.move('football-players-detection-9/valid',
#       7             'football-players-detection-9/football-players-detection-9/valid'
#       8             )
#       9 shutil.move('football-players-detection-9/test',
#      10             'football-players-detection-9/football-players-detection-9/test'
#      11             )
#
# File c:\Program Files\Python312\Lib\shutil.py:867, in move(src, dst, copy_function)
#     865         rmtree(src)
#     866     else:
# --> 867         copy_function(src, real_dst)
#     868         os.unlink(src)
#     869 return real_dst
#
# File c:\Program Files\Python312\Lib\shutil.py:460, in copy2(src, dst, follow_symlinks)
#     458     flags |= _winapi.COPY_FILE_COPY_SYMLINK
#     459 try:
# --> 460     _winapi.CopyFile2(src_, dst_, flags)
#     461     return dst
#     462 except OSError as exc:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5s.pt data={dataset.location}/data.yaml epochs=10 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov5su.pt to 'yolov5su.pt'...
# New https://pypi.org/project/ultralytics/8.2.60 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.59 🚀 Python-3.12.4 torch-2.3.1+cpu CPU (AMD Ryzen 5 6600H with Radeon Graphics)
# engine\trainer: task=detect, mode=train, model=yolov5s.pt, data=(dataset.location)/data.yaml, epochs=100, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train
#   0%|          | 0.00/17.7M [00:00<?, ?B/s]
#   1%|          | 128k/17.7M [00:00<00:31, 589kB/s]
#   1%|▏         | 256k/17.7M [00:00<00:28, 645kB/s]
#   2%|▏         | 384k/17.7M [00:00<00:26, 690kB/s]
#   3%|▎         | 512k/17.7M [00:00<00:30, 598kB/s]
#   4%|▍         | 768k/17.7M [00:01<00:21, 835kB/s]
#   5%|▍         | 896k/17.7M [00:01<00:19, 897kB/s]
#   6%|▋         | 1.12M/17.7M [00:01<00:15, 1.15MB/s]
#   8%|▊         | 1.38M/17.7M [00:01<00:20, 840kB/s]
#   9%|▉         | 1.62M/17.7M [00:02<00:28, 597kB/s]
#  10%|▉         | 1.75M/17.7M [00:02<00:28, 591kB/s]
#  11%|█         | 1.88M/17.7M [00:03<00:32, 518kB/s]
#  11%|█▏        | 2.00M/17.7M [00:03<00:40, 405kB/s]
#  12%|█▏        | 2.12M/17.7M [00:04<00:50, 321kB/s]
#  13%|█▎        | 2.25M/17.7M [00:05<01:22, 197kB/s]
#  13%|█▎        | 2.38M/17.7M [00:06<01:13, 219kB/s]
#  58%|█████▊    | 10.2M/17.7M [00:19<00:06, 1.29MB/s]
#  59%|█████▉    | 10.5M/17.7M [00:19<00:06, 1.17MB/s]
#  61%|██████    | 10.8M/17.7M [00:20<00:09, 805kB/s]
#  62%|██████▏   | 11.0M/17.7M [00:20<00:07, 996kB/s]
#  63%|██████▎   | 11.2M/17.7M [00:20<00:05, 1.13MB/s]
#  65%|██████▍   | 11.5M/17.7M [00:20<00:06, 1.08MB/s]
#  66%|██████▋   | 11.8M/17.7M [00:21<00:06, 1.02MB/s]
#  68%|██████▊   | 12.0M/17.7M [00:21<00:04, 1.23MB/s]
#  69%|██████▉   | 12.2M/17.7M [00:21<00:05, 975kB/s]
#  71%|███████   | 12.5M/17.7M [00:21<00:06, 884kB/s]
#  72%|███████▏  | 12.8M/17.7M [00:22<00:05, 1.04MB/s]
#  73%|███████▎  | 12.9M/17.7M [00:22<00:06, 830kB/s]
#  74%|███████▍  | 13.1M/17.7M [00:22<00:05, 956kB/s]
#  75%|███████▍  | 13.2M/17.7M [00:22<00:05, 836kB/s]
#  76%|███████▌  | 13.5M/17.7M [00:22<00:04, 1.01MB/s]
#  77%|███████▋  | 13.6M/17.7M [00:23<00:04, 872kB/s]
#  78%|███████▊  | 13.9M/17.7M [00:23<00:03, 1.10MB/s]
#  80%|███████▉  | 14.1M/17.7M [00:23<00:03, 1.05MB/s]
#  81%|████████  | 14.4M/17.7M [00:23<00:03, 1.13MB/s]
#  82%|████████▏ | 14.5M/17.7M [00:24<00:03, 845kB/s]
#  83%|████████▎ | 14.6M/17.7M [00:24<00:03, 865kB/s]
#  83%|████████▎ | 14.8M/17.7M [00:24<00:04, 672kB/s]
#  85%|████████▍ | 15.0M/17.7M [00:24<00:03, 922kB/s]
#  86%|████████▌ | 15.2M/17.7M [00:24<00:02, 1.13MB/s]
#  87%|████████▋ | 15.5M/17.7M [00:25<00:02, 1.04MB/s]
#  88%|████████▊ | 15.6M/17.7M [00:25<00:02, 1.00MB/s]
#  90%|████████▉ | 15.9M/17.7M [00:25<00:01, 1.14MB/s]
#  91%|█████████ | 16.1M/17.7M [00:25<00:01, 978kB/s]
#  92%|█████████▏| 16.2M/17.7M [00:25<00:01, 957kB/s]
#  92%|█████████▏| 16.4M/17.7M [00:26<00:02, 571kB/s]
#  93%|█████████▎| 16.5M/17.7M [00:26<00:01, 654kB/s]
#  94%|█████████▍| 16.6M/17.7M [00:26<00:01, 577kB/s]
#  95%|█████████▍| 16.8M/17.7M [00:27<00:01, 651kB/s]
#  95%|█████████▌| 16.9M/17.7M [00:27<00:01, 505kB/s]
#  97%|█████████▋| 17.1M/17.7M [00:27<00:01, 557kB/s]
#  98%|█████████▊| 17.4M/17.7M [00:28<00:00, 536kB/s]
#  99%|█████████▉| 17.6M/17.7M [00:28<00:00, 586kB/s]
# 100%|██████████| 17.7M/17.7M [00:28<00:00, 647kB/s]
# Traceback (most recent call last):
#   File "C:\Users\rafig\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\trainer.py", line 527, in get_dataset
#     data = check_det_dataset(self.args.data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rafig\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\data\utils.py", line 269, in check_det_dataset
#     file = check_file(dataset)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rafig\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\utils\checks.py", line 509, in check_file
#     raise FileNotFoundError(f"'{file}' does not exist")
# FileNotFoundError: '(dataset.location)/data.yaml' does not exist
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\rafig\AppData\Local\Programs\Python\Python312\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\rafig\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\cfg\__init__.py", line 708, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rafig\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\model.py", line 646, in train
#     self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rafig\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\trainer.py", line 132, in __init__
#     self.trainset, self.testset = self.get_dataset()
#                                   ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rafig\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\trainer.py", line 531, in get_dataset
#     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
# RuntimeError: Dataset '(dataset.location)/data.yaml' error  '(dataset.location)/data.yaml' does not exist
